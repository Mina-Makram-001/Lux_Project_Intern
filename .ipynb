# %%
from Functions import *
import pandas as pd
from rapidfuzz import process, fuzz

# %%
# Load the Excel files

df_1_DATA = load_excel(r"D:\Projects\Lux_Project_Intern\Data\1_DATA.xlsx")
df_2_LIST_OF_COLUMNS = load_excel(r"D:\Projects\Lux_Project_Intern\Data\2_LIST_OF_COLUMNS.xlsx")
df_3_LOB = load_excel(r"D:\Projects\Lux_Project_Intern\Data\3_LOB.xlsx")
df_4_TESTS = load_excel(r"D:\Projects\Lux_Project_Intern\Data\4_TESTS.xlsx")
df_5_FINANCIALS = load_excel(r"D:\Projects\Lux_Project_Intern\Data\5_FINANCIALS.xlsx")

# %%
# Clean and align the columns of df_1_DATA based on the column names in df_2_LIST_OF_COLUMNS

df_1_DATA = clean_and_align_columns(df_1_DATA, df_2_LIST_OF_COLUMNS['Column Names'].tolist())
df_1_DATA
# Out:
#    LA_AS_AT_DATE      LA_POLICY_NUMBER    LA_CLAIM_NUMBER  \
# 0     2025-12-31  22/100/20010/0003589  C/24/100/20/01611
# 1     2025-12-31  23/100/20010/0004000  C/25/100/20/01883
# 2     2025-12-31    21/100/20010/02804  C/25/100/20/01887
# 3     2025-12-31  25/100/20010/0004489  C/25/100/20/01942
# 4     2025-12-31  25/100/20010/0004392  C/25/100/20/01989
# ..           ...                   ...                ...
# 78    2025-06-30    19/100/40010/05677  C/19/100/45/02868
# 79    2025-06-30    19/100/40010/05678  C/19/100/45/02888
# 80    2025-06-30    19/100/40010/05678  C/19/100/45/02889
# 81    2025-06-30    18/100/40010/05569  C/19/100/45/03015
# 82    2025-06-30    19/100/40010/05645  C/20/100/45/03196
#
#                  LA_LOB LA_LOSS_DATE LA_PAYMENT_DATE LA_STATUS  \
# 0                   Eng   2024-05-18      2025-11-25      Paid
# 1                   Eng   2025-05-13      2025-11-20      Paid
# 2                   Eng   2025-04-30      2025-12-21      Paid
# 3                   Eng   2025-07-26      2025-12-24      Paid
# 4                   Eng   2025-10-03      2025-12-07      Paid
# ..                  ...          ...             ...       ...
# 78  Motor Comprehensive   2015-03-06             NaT        OS
# 79  Motor Comprehensive   2016-05-04             NaT        OS
# 80  Motor Comprehensive   2017-07-25             NaT        OS
# 81  Motor Comprehensive   2018-06-30             NaT        OS
# 82  Motor Comprehensive   2019-12-17             NaT        OS
#
#     LA_GROSS_AMOUNT  LA_CEDED_AMOUNT
# 0         734052.79              NaN
# 1         806656.00              NaN
# 2          22000.00              NaN
# 3          16500.00              NaN
# 4         413750.00              NaN
# ..              ...              ...
# 78              NaN         105576.0
# 79              NaN           1194.0
# 80              NaN           8000.0
# 81              NaN         120000.0
# 82              NaN            480.0
#
# [83 rows x 9 columns]
